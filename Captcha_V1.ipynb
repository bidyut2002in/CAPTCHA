# %%
import cv2
import numpy as np

# Loading our images
# Background/Input image
background = cv2.imread('/content/drive/MyDrive/Colab Notebooks/captcha/1.png')

# Overlay image
overlay_image = cv2.imread('/content/drive/MyDrive/Colab Notebooks/captcha/2.png')
overlay_image1 = cv2.imread('/content/drive/MyDrive/Colab Notebooks/captcha/5.png')

# Resize the overlay image to match the bg image dimensions
#overlay_image = cv2.resize(overlay_image, (1000, 1000))
#h, w = overlay_image.shape[:2]

# Create a new np array
#shapes = np.zeros_like(background, np.uint8)

# Put the overlay at the bottom-right corner
#shapes[background.shape[0]-h:, background.shape[1]-w:] = overlay_image

# Change this into bool to use it as mask
#mask = shapes.astype(bool)

# We'll create a loop to change the alpha
# value i.e transparency of the overlay
#for alpha in np.arange(0, 1.1, 0.1)[::-1]:
alpha=0.5;
    # Create a copy of the image to work with
bg_img = background.copy()
    # Create the overlay
bg_img = cv2.addWeighted(background, 0.5, overlay_image, alpha, 0)
bg_img1 = cv2.addWeighted(bg_img, 0.5, overlay_image1, alpha, 0)

    # print the alpha value on the image
    #cv2.putText(bg_img, f'Alpha: {round(alpha,1)}', (50, 200),
    #cv2.FONT_HERSHEY_PLAIN, 8, (200, 200, 200), 7)

    # resize the image before displaying
    #bg_img = cv2.resize(bg_img, (630, 630))
cv2.imwrite('data_new1/1_new.png', bg_img1)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-2-621179b6afd8> in <cell line: 33>()
#      31     # Create the overlay
#      32 bg_img = cv2.addWeighted(background, 0.5, overlay_image, alpha, 0)
# ---> 33 bg_img1 = cv2.addWeighted(bg_img, 0.5, overlay_image1, alpha, 0)
#      34
#      35     # print the alpha value on the image
#
# error: OpenCV(4.8.0) /io/opencv/modules/core/src/arithm.cpp:647: error: (-209:Sizes of input arguments do not match) The operation is neither 'array op array' (where arrays have the same size and the same number of channels), nor 'array op scalar', nor 'scalar op array' in function 'arithm_op'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
