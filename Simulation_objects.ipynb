# %%
import random
from random import randint
random.seed()
from PIL import Image, ImageDraw, ImageOps
import matplotlib.image as image
import csv
import numpy as np

#Parameters
canvas_W=512
canvas_H=512
padding=10
numbers_of_questions=5001
max_image_variation=2

imgs=[]          
imgs.append(Image.open('objects/sun.png').convert("RGBA"))
imgs.append(Image.open('objects/tree.png').convert("RGBA"))
imgs.append(Image.open('objects/hut.png').convert("RGBA"))
imgs.append(Image.open('objects/balloon.png').convert("RGBA"))
imgs.append(Image.open('objects/ball.png').convert("RGBA"))
imgs.append(Image.open('objects/car.png').convert("RGBA"))
imgs.append(Image.open('objects/cup.png').convert("RGBA"))
imgs.append(Image.open('objects/fish.png').convert("RGBA"))
imgs.append(Image.open('objects/flower.png').convert("RGBA"))
imgs.append(Image.open('objects/pencil.png').convert("RGBA"))
imgs.append(Image.open('objects/apple.png').convert("RGBA"))
imgs.append(Image.open('objects/icecream.png').convert("RGBA"))
imgs.append(Image.open('objects/ant.png').convert("RGBA"))
imgs.append(Image.open('objects/banana.png').convert("RGBA"))
imgs.append(Image.open('objects/bird.png').convert("RGBA"))
imgs.append(Image.open('objects/butterfly.png').convert("RGBA"))
imgs.append(Image.open('objects/carrot.png').convert("RGBA"))
imgs.append(Image.open('objects/cupcake.png').convert("RGBA"))
imgs.append(Image.open('objects/duck.png').convert("RGBA"))
imgs.append(Image.open('objects/ladybug.png').convert("RGBA"))
imgs.append(Image.open('objects/lollipop.png').convert("RGBA"))
imgs.append(Image.open('objects/mango.png').convert("RGBA"))
imgs.append(Image.open('objects/octopus.png').convert("RGBA"))
imgs.append(Image.open('objects/orange.png').convert("RGBA"))
imgs.append(Image.open('objects/owl.png').convert("RGBA"))
imgs.append(Image.open('objects/pineapple.png').convert("RGBA"))
imgs.append(Image.open('objects/shark.png').convert("RGBA"))
imgs.append(Image.open('objects/teapot.png').convert("RGBA"))
imgs.append(Image.open('objects/teddy.png').convert("RGBA"))
imgs.append(Image.open('objects/umbrella.png').convert("RGBA"))
imgs.append(Image.open('objects/cap.png').convert("RGBA"))
imgs.append(Image.open('objects/dog.png').convert("RGBA"))
imgs.append(Image.open('objects/elephant.png').convert("RGBA"))
imgs.append(Image.open('objects/frog.png').convert("RGBA"))
imgs.append(Image.open('objects/lion.png').convert("RGBA"))
imgs.append(Image.open('objects/snake.png').convert("RGBA"))
imgs.append(Image.open('objects/zirafah.png').convert("RGBA"))
imgs.append(Image.open('objects/top.png').convert("RGBA"))
imgs.append(Image.open('objects/pumpkin.png').convert("RGBA"))
imgs.append(Image.open('objects/corn.png').convert("RGBA"))
imgs.append(Image.open('objects/caterpillar.png').convert("RGBA"))
imgs.append(Image.open('objects/pig.png').convert("RGBA"))
imgs.append(Image.open('objects/cow.png').convert("RGBA"))
imgs.append(Image.open('objects/spider.png').convert("RGBA"))
imgs.append(Image.open('objects/rabbit.png').convert("RGBA"))
imgs.append(Image.open('objects/lamp.png').convert("RGBA"))
imgs.append(Image.open('objects/bell.png').convert("RGBA"))

image_name=['sun','tree','hut','balloon','ball','car','cup','fish','flower','pencil','apple','icecream',
            'ant','banana','bird','butterfly','carrot','cupcake','duck','ladybug','lollipop','mango',
            'octopus','orange','owl','pineapple','shark','eapot','teddy','umbrella','cap','dog','elephant',
            'frog','lion','snake','zirafah','top','pumpkin','corn','caterpillar','pig','cow','spider',
            'rabbit','lamp','bell']

alpha=["zero","one","two","three","four","five","six","seven","eight","nine"]

# %%
import copy
def add_coordinate(image_no,X,Y,W,H,class_name):
    # csv1: image_no, x, y, w, h, class
    file=open('CSV/obj_csv1.csv', 'a+', newline='')
    writer = csv.writer(file)
    writer.writerow([image_no, X, Y, W, H,class_name])
    file.close()  
def add_image(frame,canvas,img_list1,obj_name,total,start):
    if(frame>0):
        if(total==1):
            img_list=copy.deepcopy(img_list1)
            img=img_list[0]
            box_W=int((canvas_W)/2)
            box_H=int((canvas_H)/2)
            img_W=img.width
            img_H=img.height
            px=int(box_W/2)-int(box_W/4)
            py=int(box_H/2)-int(box_H/4)
            if(img_W>=img_H):
                ratio=box_W/img_W
            if(img_W<=img_H):
                ratio=box_H/img_H
            if(ratio>1):
                ratio=1
            W=int(img_W*ratio)
            H=int(img_H*ratio)
            newsize = (W,H)
            img = ImageOps.fit(img, newsize, Image.ANTIALIAS)
            canvas.paste(img,(px+80,py+80),mask=img.split()[3])
            add_coordinate(start,px+80,py+80,W,H,obj_name[0])
        if(total==2):
            #1st image
            img_list=copy.deepcopy(img_list1)
            img=img_list[0]
            box_W=int((canvas_W)/3)
            box_H=int((canvas_H)/3)
            img_W=img.width
            img_H=img.height
            px=int(box_W/4)
            py=int(box_H/2)
            if(img_W>=img_H):
                ratio=box_W/img_W
            if(img_W<=img_H):
                ratio=box_H/img_H
            if(ratio>1):
                ratio=1
            W=int(img_W*ratio)
            H=int(img_H*ratio)
            newsize = (W,H)
            img = ImageOps.fit(img, newsize, Image.ANTIALIAS)
            canvas.paste(img,(px,py),mask=img.split()[3])
            add_coordinate(start,px,py,W,H,obj_name[0])
            
            #2nd image
            img_list=copy.deepcopy(img_list1)
            img=img_list[1]
            img_W=img.width
            img_H=img.height
            px=int(box_W/2)
            py=int(box_H/2)
            if(img_W>=img_H):
                ratio=box_W/img_W
            if(img_W<=img_H):
                ratio=box_H/img_H
            if(ratio>1):
                ratio=1
            W=int(img_W*ratio)
            H=int(img_H*ratio)
            newsize = (W,H)
            img = ImageOps.fit(img, newsize, Image.ANTIALIAS)
            px=int(px+box_W)
            canvas.paste(img,(px,py),mask=img.split()[3])
            add_coordinate(start,px,py,W,H,obj_name[1])
                     
        if(total==3):
            #1st image
            img_list=copy.deepcopy(img_list1)
            img=img_list[0]
            box_W=int((canvas_W)/3)
            box_H=int((canvas_H)/3)
            img_W=img.width
            img_H=img.height
            px=int(box_W/4)
            py=int(box_H/4)
            if(img_W>=img_H):
                ratio=box_W/img_W
            if(img_W<=img_H):
                ratio=box_H/img_H
            if(ratio>1):
                ratio=1
            W=int(img_W*ratio)
            H=int(img_H*ratio)
            newsize = (W,H)
            img = ImageOps.fit(img, newsize, Image.ANTIALIAS)
            canvas.paste(img,(px,py),mask=img.split()[3])
            add_coordinate(start,px,py,W,H,obj_name[0])
                     
            #2nd image
            img_list=copy.deepcopy(img_list1)
            img=img_list[1]
            box_W=int((canvas_W)/3)
            box_H=int((canvas_H)/3)
            img_W=img.width
            img_H=img.height
            px=int(box_W/4)
            py=int(box_H/4)
            if(img_W>=img_H):
                ratio=box_W/img_W
            if(img_W<=img_H):
                ratio=box_H/img_H
            if(ratio>1):
                ratio=1
            W=int(img_W*ratio)
            H=int(img_H*ratio)
            newsize = (W,H)
            img = ImageOps.fit(img, newsize, Image.ANTIALIAS)
            px2=int(px+box_W*1.3)
            canvas.paste(img,(px2,py),mask=img.split()[3])
            add_coordinate(start,px2,py,W,H,obj_name[1])
                     
            #3rd image
            img_list=copy.deepcopy(img_list1)
            img=img_list[2]
            box_W=int((canvas_W)/3)
            box_H=int((canvas_H)/3)
            img_W=img.width
            img_H=img.height
            px=int(box_W/4)
            py=int(box_H/4)
            if(img_W>=img_H):
                ratio=box_W/img_W
            if(img_W<=img_H):
                ratio=box_H/img_H
            if(ratio>1):
                ratio=1
            W=int(img_W*ratio)
            H=int(img_H*ratio)
            newsize = (W,H)
            img = ImageOps.fit(img, newsize, Image.ANTIALIAS)
            px3=int(px+px2/2)
            py3=int(py+box_H*1.3)
            canvas.paste(img,(px3,py3),mask=img.split()[3])
            add_coordinate(start,px3,py3,W,H,obj_name[2])
                     
        if(total==4):
            #1st image
            img_list=copy.deepcopy(img_list1)
            img=img_list[0]
            box_W=int((canvas_W)/3)
            box_H=int((canvas_H)/3)
            img_W=img.width
            img_H=img.height
            px=int(box_W/4)
            py=int(box_H/4)
            if(img_W>=img_H):
                ratio=box_W/img_W
            if(img_W<=img_H):
                ratio=box_H/img_H
            if(ratio>1):
                ratio=1
            W=int(img_W*ratio)
            H=int(img_H*ratio)
            newsize = (W,H)
            img = ImageOps.fit(img, newsize, Image.ANTIALIAS)
            canvas.paste(img,(px,py),mask=img.split()[3])
            add_coordinate(start,px,py,W,H,obj_name[0])
                     
            #2nd image
            img_list=copy.deepcopy(img_list1)
            img=img_list[1]
            box_W=int((canvas_W)/3)
            box_H=int((canvas_H)/3)
            img_W=img.width
            img_H=img.height
            px=int(box_W/4)
            py=int(box_H/4)
            if(img_W>=img_H):
                ratio=box_W/img_W
            if(img_W<=img_H):
                ratio=box_H/img_H
            if(ratio>1):
                ratio=1
            W=int(img_W*ratio)
            H=int(img_H*ratio)
            newsize = (W,H)
            img = ImageOps.fit(img, newsize, Image.ANTIALIAS)
            px2=int(px+box_W*1.3)
            canvas.paste(img,(px2,py),mask=img.split()[3])
            add_coordinate(start,px2,py,W,H,obj_name[1])
                     
            #3rd image
            img_list=copy.deepcopy(img_list1)
            img=img_list[2]
            box_W=int((canvas_W)/3)
            box_H=int((canvas_H)/3)
            img_W=img.width
            img_H=img.height
            px=int(box_W/4)
            py=int(box_H/4)
            if(img_W>=img_H):
                ratio=box_W/img_W
            if(img_W<=img_H):
                ratio=box_H/img_H
            if(ratio>1):
                ratio=1
            W=int(img_W*ratio)
            H=int(img_H*ratio)
            newsize = (W,H)
            img = ImageOps.fit(img, newsize, Image.ANTIALIAS)
            px3=int(px)
            py3=int(py+box_H*1.3)
            canvas.paste(img,(px3,py3),mask=img.split()[3])
            add_coordinate(start,px3,py3,W,H,obj_name[2])
                     
            #4th image
            img_list=copy.deepcopy(img_list1)
            img=img_list[3]
            box_W=int((canvas_W)/3)
            box_H=int((canvas_H)/3)
            img_W=img.width
            img_H=img.height
            px=int(box_W/4)
            py=int(box_H/4)
            if(img_W>=img_H):
                ratio=box_W/img_W
            if(img_W<=img_H):
                ratio=box_H/img_H
            if(ratio>1):
                ratio=1
            W=int(img_W*ratio)
            H=int(img_H*ratio)
            newsize = (W,H)
            img = ImageOps.fit(img, newsize, Image.ANTIALIAS)
            px4=int(px2)
            py4=int(py3)
            canvas.paste(img,(px4,py4),mask=img.split()[3])
            add_coordinate(start,px4,py4,W,H,obj_name[3])
            
        if(total==5):
            #1st image
            img_list=copy.deepcopy(img_list1)
            img=img_list[0]
            box_W=int((canvas_W)/4)
            box_H=int((canvas_H)/4)
            img_W=img.width
            img_H=img.height
            px=int(box_W/4)
            py=int(box_H/4)
            if(img_W>=img_H):
                ratio=box_W/img_W
            if(img_W<=img_H):
                ratio=box_H/img_H
            if(ratio>1):
                ratio=1
            W=int(img_W*ratio)
            H=int(img_H*ratio)
            newsize = (W,H)
            img = ImageOps.fit(img, newsize, Image.ANTIALIAS)
            canvas.paste(img,(px,py),mask=img.split()[3])
            add_coordinate(start,px,py,W,H,obj_name[0])
                     
            #2nd image
            img_list=copy.deepcopy(img_list1)
            img=img_list[1]
            img_W=img.width
            img_H=img.height
            if(img_W>=img_H):
                ratio=box_W/img_W
            if(img_W<=img_H):
                ratio=box_H/img_H
            if(ratio>1):
                ratio=1
            W=int(img_W*ratio)
            H=int(img_H*ratio)
            newsize = (W,H)
            img = ImageOps.fit(img, newsize, Image.ANTIALIAS)
            px2=int(px+box_W*1.2)
            py2=py
            canvas.paste(img,(px2,py2),mask=img.split()[3])
            add_coordinate(start,px2,py2,W,H,obj_name[1])
                     
            #3rd image
            img_list=copy.deepcopy(img_list1)
            img=img_list[2]
            img_W=img.width
            img_H=img.height
            if(img_W>=img_H):
                ratio=box_W/img_W
            if(img_W<=img_H):
                ratio=box_H/img_H
            if(ratio>1):
                ratio=1
            W=int(img_W*ratio)
            H=int(img_H*ratio)
            newsize = (W,H)
            img = ImageOps.fit(img, newsize, Image.ANTIALIAS)
            px3=int(px2+box_W*1.2)
            py3=py
            canvas.paste(img,(px3,py3),mask=img.split()[3])
            add_coordinate(start,px3,py3,W,H,obj_name[2])
                     
            #4th image
            img_list=copy.deepcopy(img_list1)
            img=img_list[3]
            img_W=img.width
            img_H=img.height
            if(img_W>=img_H):
                ratio=box_W/img_W
            if(img_W<=img_H):
                ratio=box_H/img_H
            if(ratio>1):
                ratio=1
            W=int(img_W*ratio)
            H=int(img_H*ratio)
            newsize = (W,H)
            img = ImageOps.fit(img, newsize, Image.ANTIALIAS)
            px4=int(px+box_W*0.5)
            py4=int(py+box_H*1.5)
            canvas.paste(img,(px4,py4),mask=img.split()[3])
            add_coordinate(start,px4,py4,W,H,obj_name[3])
                     
            #5th image
            img_list=copy.deepcopy(img_list1)
            img=img_list[4]
            img_W=img.width
            img_H=img.height
            if(img_W>=img_H):
                ratio=box_W/img_W
            if(img_W<=img_H):
                ratio=box_H/img_H
            if(ratio>1):
                ratio=1
            W=int(img_W*ratio)
            H=int(img_H*ratio)
            newsize = (W,H)
            img = ImageOps.fit(img, newsize, Image.ANTIALIAS)
            px5=int(px2+box_W*0.5)
            py5=int(py+box_H*1.5)
            canvas.paste(img,(px5,py5),mask=img.split()[3])
            add_coordinate(start,px5,py5,W,H,obj_name[4])
           
            
        if(total==6):
            #1st image
            img_list=copy.deepcopy(img_list1)
            img=img_list[0]
            box_W=int((canvas_W)/4)
            box_H=int((canvas_H)/4)
            img_W=img.width
            img_H=img.height
            px=int(box_W/4)
            py=int(box_H/4)
            if(img_W>=img_H):
                ratio=box_W/img_W
            if(img_W<=img_H):
                ratio=box_H/img_H
            if(ratio>1):
                ratio=1
            W=int(img_W*ratio)
            H=int(img_H*ratio)
            newsize = (W,H)
            img = ImageOps.fit(img, newsize, Image.ANTIALIAS)
            canvas.paste(img,(px,py),mask=img.split()[3])
            add_coordinate(start,px,py,W,H,obj_name[0])
                     
            #2nd image
            img_list=copy.deepcopy(img_list1)
            img=img_list[1]
            img_W=img.width
            img_H=img.height
            if(img_W>=img_H):
                ratio=box_W/img_W
            if(img_W<=img_H):
                ratio=box_H/img_H
            if(ratio>1):
                ratio=1
            W=int(img_W*ratio)
            H=int(img_H*ratio)
            newsize = (W,H)
            img = ImageOps.fit(img, newsize, Image.ANTIALIAS)
            px2=int(px+box_W*1.2)
            py2=py
            canvas.paste(img,(px2,py2),mask=img.split()[3])
            add_coordinate(start,px2,py2,W,H,obj_name[1])
                     
            #3rd image
            img_list=copy.deepcopy(img_list1)
            img=img_list[2]
            img_W=img.width
            img_H=img.height
            if(img_W>=img_H):
                ratio=box_W/img_W
            if(img_W<=img_H):
                ratio=box_H/img_H
            if(ratio>1):
                ratio=1
            W=int(img_W*ratio)
            H=int(img_H*ratio)
            newsize = (W,H)
            img = ImageOps.fit(img, newsize, Image.ANTIALIAS)
            px3=int(px2+box_W*1.2)
            py3=py
            canvas.paste(img,(px3,py3),mask=img.split()[3])
            add_coordinate(start,px3,py3,W,H,obj_name[2])
                     
            #4th image
            img_list=copy.deepcopy(img_list1)
            img=img_list[3]
            img_W=img.width
            img_H=img.height
            if(img_W>=img_H):
                ratio=box_W/img_W
            if(img_W<=img_H):
                ratio=box_H/img_H
            if(ratio>1):
                ratio=1
            W=int(img_W*ratio)
            H=int(img_H*ratio)
            newsize = (W,H)
            img = ImageOps.fit(img, newsize, Image.ANTIALIAS)
            px4=px
            py4=int(py+box_H*1.5)
            canvas.paste(img,(px4,py4),mask=img.split()[3])
            add_coordinate(start,px4,py4,W,H,obj_name[3])
                     
            #5th image
            img_list=copy.deepcopy(img_list1)
            img=img_list[4]
            img_W=img.width
            img_H=img.height
            if(img_W>=img_H):
                ratio=box_W/img_W
            if(img_W<=img_H):
                ratio=box_H/img_H
            if(ratio>1):
                ratio=1
            W=int(img_W*ratio)
            H=int(img_H*ratio)
            newsize = (W,H)
            img = ImageOps.fit(img, newsize, Image.ANTIALIAS)
            px5=px2
            py5=int(py+box_H*1.5)
            canvas.paste(img,(px5,py5),mask=img.split()[3])
            add_coordinate(start,px5,py5,W,H,obj_name[4])
                     
            #6th image
            img_list=copy.deepcopy(img_list1)
            img=img_list[5]
            img_W=img.width
            img_H=img.height
            if(img_W>=img_H):
                ratio=box_W/img_W
            if(img_W<=img_H):
                ratio=box_H/img_H
            if(ratio>1):
                ratio=1
            W=int(img_W*ratio)
            H=int(img_H*ratio)
            newsize = (W,H)
            img = ImageOps.fit(img, newsize, Image.ANTIALIAS)
            px6=px3
            py6=int(py+box_H*1.5)
            canvas.paste(img,(px6,py6),mask=img.split()[3])
            add_coordinate(start,px6,py6,W,H,obj_name[5])
            
        if(total==7):
            #1st image
            img_list=copy.deepcopy(img_list1)
            img=img_list[0]
            box_W=int((canvas_W)/4)
            box_H=int((canvas_H)/5)
            img_W=img.width
            img_H=img.height
            px=int(box_W/4)
            py=int(box_H/4)
            if(img_W>=img_H):
                ratio=box_W/img_W
            if(img_W<=img_H):
                ratio=box_H/img_H
            if(ratio>1):
                ratio=1
            W=int(img_W*ratio)
            H=int(img_H*ratio)
            newsize = (W,H)
            img = ImageOps.fit(img, newsize, Image.ANTIALIAS)
            canvas.paste(img,(px,py),mask=img.split()[3])
            add_coordinate(start,px,py,W,H,obj_name[0])
            
            #2nd image
            img_list=copy.deepcopy(img_list1)
            img=img_list[1]
            img_W=img.width
            img_H=img.height
            px=int(box_W/4)
            py=int(box_H/4)
            if(img_W>=img_H):
                ratio=box_W/img_W
            if(img_W<=img_H):
                ratio=box_H/img_H
            if(ratio>1):
                ratio=1
            W=int(img_W*ratio)
            H=int(img_H*ratio)
            newsize = (W,H)
            img = ImageOps.fit(img, newsize, Image.ANTIALIAS)
            px2=int(px+box_W*1.2)
            py2=py
            canvas.paste(img,(px2,py2),mask=img.split()[3])
            add_coordinate(start,px2,py2,W,H,obj_name[1])
            
            #3rd image
            img_list=copy.deepcopy(img_list1)
            img=img_list[2]
            img_W=img.width
            img_H=img.height
            px=int(box_W/4)
            py=int(box_H/4)
            if(img_W>=img_H):
                ratio=box_W/img_W
            if(img_W<=img_H):
                ratio=box_H/img_H
            if(ratio>1):
                ratio=1
            W=int(img_W*ratio)
            H=int(img_H*ratio)
            newsize = (W,H)
            img = ImageOps.fit(img, newsize, Image.ANTIALIAS)
            px3=int(px2+box_W*1.2)
            py3=py
            canvas.paste(img,(px3,py3),mask=img.split()[3])
            add_coordinate(start,px3,py3,W,H,obj_name[2])
            
            #4th image
            img_list=copy.deepcopy(img_list1)
            img=img_list[3]
            img_W=img.width
            img_H=img.height
            px=int(box_W/4)
            py=int(box_H/4)
            if(img_W>=img_H):
                ratio=box_W/img_W
            if(img_W<=img_H):
                ratio=box_H/img_H
            if(ratio>1):
                ratio=1
            W=int(img_W*ratio)
            H=int(img_H*ratio)
            newsize = (W,H)
            img = ImageOps.fit(img, newsize, Image.ANTIALIAS)
            px4=px
            py4=int(py+box_H*1.5)
            canvas.paste(img,(px4,py4),mask=img.split()[3])
            add_coordinate(start,px4,py4,W,H,obj_name[3])
            
            #5th image
            img_list=copy.deepcopy(img_list1)
            img=img_list[4]
            img_W=img.width
            img_H=img.height
            px=int(box_W/4)
            py=int(box_H/4)
            if(img_W>=img_H):
                ratio=box_W/img_W
            if(img_W<=img_H):
                ratio=box_H/img_H
            if(ratio>1):
                ratio=1
            W=int(img_W*ratio)
            H=int(img_H*ratio)
            newsize = (W,H)
            img = ImageOps.fit(img, newsize, Image.ANTIALIAS)
            px5=px2
            py5=int(py+box_H*1.5)
            canvas.paste(img,(px5,py5),mask=img.split()[3])
            add_coordinate(start,px5,py5,W,H,obj_name[4])
            
            #6th image
            img_list=copy.deepcopy(img_list1)
            img=img_list[5]
            img_W=img.width
            img_H=img.height
            px=int(box_W/4)
            py=int(box_H/4)
            if(img_W>=img_H):
                ratio=box_W/img_W
            if(img_W<=img_H):
                ratio=box_H/img_H
            if(ratio>1):
                ratio=1
            W=int(img_W*ratio)
            H=int(img_H*ratio)
            newsize = (W,H)
            img = ImageOps.fit(img, newsize, Image.ANTIALIAS)
            px6=px3
            py6=int(py+box_H*1.5)
            canvas.paste(img,(px6,py6),mask=img.split()[3])
            add_coordinate(start,px6,py6,W,H,obj_name[5])
                        
            #7th image
            img_list=copy.deepcopy(img_list1)
            img=img_list[6]
            img_W=img.width
            img_H=img.height
            px=int(box_W/4)
            py=int(box_H/4)
            if(img_W>=img_H):
                ratio=box_W/img_W
            if(img_W<=img_H):
                ratio=box_H/img_H
            if(ratio>1):
                ratio=1
            W=int(img_W*ratio)
            H=int(img_H*ratio)
            newsize = (W,H)
            img = ImageOps.fit(img, newsize, Image.ANTIALIAS)
            px7=px2
            py7=int(py5+box_H*1.5)
            canvas.paste(img,(px7,py7),mask=img.split()[3])
            add_coordinate(start,px7,py7,W,H,obj_name[6])
            
        if(total==8):
            #1st image
            img_list=copy.deepcopy(img_list1)
            img=img_list[0]
            box_W=int((canvas_W)/4)
            box_H=int((canvas_H)/5)
            img_W=img.width
            img_H=img.height
            px=int(box_W/4)
            py=int(box_H/4)
            if(img_W>=img_H):
                ratio=box_W/img_W
            if(img_W<=img_H):
                ratio=box_H/img_H
            if(ratio>1):
                ratio=1
            W=int(img_W*ratio)
            H=int(img_H*ratio)
            newsize = (W,H)
            img = ImageOps.fit(img, newsize, Image.ANTIALIAS)
            canvas.paste(img,(px,py),mask=img.split()[3])
            add_coordinate(start,px,py,W,H,obj_name[0])
            
            #2nd image
            img_list=copy.deepcopy(img_list1)
            img=img_list[1]
            img_W=img.width
            img_H=img.height
            px=int(box_W/4)
            py=int(box_H/4)
            if(img_W>=img_H):
                ratio=box_W/img_W
            if(img_W<=img_H):
                ratio=box_H/img_H
            if(ratio>1):
                ratio=1
            W=int(img_W*ratio)
            H=int(img_H*ratio)
            newsize = (W,H)
            img = ImageOps.fit(img, newsize, Image.ANTIALIAS)
            px2=int(px+box_W*1.2)
            py2=py
            canvas.paste(img,(px2,py2),mask=img.split()[3])
            add_coordinate(start,px2,py2,W,H,obj_name[1])
            
            #3rd image
            img_list=copy.deepcopy(img_list1)
            img=img_list[2]
            img_W=img.width
            img_H=img.height
            px=int(box_W/4)
            py=int(box_H/4)
            if(img_W>=img_H):
                ratio=box_W/img_W
            if(img_W<=img_H):
                ratio=box_H/img_H
            if(ratio>1):
                ratio=1
            W=int(img_W*ratio)
            H=int(img_H*ratio)
            newsize = (W,H)
            img = ImageOps.fit(img, newsize, Image.ANTIALIAS)
            px3=int(px2+box_W*1.2)
            py3=py
            canvas.paste(img,(px3,py3),mask=img.split()[3])
            add_coordinate(start,px3,py3,W,H,obj_name[2])
            
            #4th image
            img_list=copy.deepcopy(img_list1)
            img=img_list[3]
            img_W=img.width
            img_H=img.height
            px=int(box_W/4)
            py=int(box_H/4)
            if(img_W>=img_H):
                ratio=box_W/img_W
            if(img_W<=img_H):
                ratio=box_H/img_H
            if(ratio>1):
                ratio=1
            W=int(img_W*ratio)
            H=int(img_H*ratio)
            newsize = (W,H)
            img = ImageOps.fit(img, newsize, Image.ANTIALIAS)
            px4=px
            py4=int(py+box_H*1.5)
            canvas.paste(img,(px4,py4),mask=img.split()[3])
            add_coordinate(start,px4,py4,W,H,obj_name[3])
            
            #5th image
            img_list=copy.deepcopy(img_list1)
            img=img_list[4]
            img_W=img.width
            img_H=img.height
            px=int(box_W/4)
            py=int(box_H/4)
            if(img_W>=img_H):
                ratio=box_W/img_W
            if(img_W<=img_H):
                ratio=box_H/img_H
            if(ratio>1):
                ratio=1
            W=int(img_W*ratio)
            H=int(img_H*ratio)
            newsize = (W,H)
            img = ImageOps.fit(img, newsize, Image.ANTIALIAS)
            px5=px2
            py5=int(py+box_H*1.5)
            canvas.paste(img,(px5,py5),mask=img.split()[3])
            add_coordinate(start,px5,py5,W,H,obj_name[4])
            
            #6th image
            img_list=copy.deepcopy(img_list1)
            img=img_list[5]
            img_W=img.width
            img_H=img.height
            px=int(box_W/4)
            py=int(box_H/4)
            if(img_W>=img_H):
                ratio=box_W/img_W
            if(img_W<=img_H):
                ratio=box_H/img_H
            if(ratio>1):
                ratio=1
            W=int(img_W*ratio)
            H=int(img_H*ratio)
            newsize = (W,H)
            img = ImageOps.fit(img, newsize, Image.ANTIALIAS)
            px6=px3
            py6=int(py+box_H*1.5)
            canvas.paste(img,(px6,py6),mask=img.split()[3])
            add_coordinate(start,px6,py6,W,H,obj_name[5])
            
            #7th image
            img_list=copy.deepcopy(img_list1)
            img=img_list[6]
            img_W=img.width
            img_H=img.height
            px=int(box_W/4)
            py=int(box_H/4)
            if(img_W>=img_H):
                ratio=box_W/img_W
            if(img_W<=img_H):
                ratio=box_H/img_H
            if(ratio>1):
                ratio=1
            W=int(img_W*ratio)
            H=int(img_H*ratio)
            newsize = (W,H)
            img = ImageOps.fit(img, newsize, Image.ANTIALIAS)
            px7=int(px2-box_W*0.5)
            py7=int(py5+box_H*1.5)
            canvas.paste(img,(px7,py7),mask=img.split()[3])
            add_coordinate(start,px7,py7,W,H,obj_name[6])
            
            #8th image
            img_list=copy.deepcopy(img_list1)
            img=img_list[7]
            img_W=img.width
            img_H=img.height
            px=int(box_W/4)
            py=int(box_H/4)
            if(img_W>=img_H):
                ratio=box_W/img_W
            if(img_W<=img_H):
                ratio=box_H/img_H
            if(ratio>1):
                ratio=1
            W=int(img_W*ratio)
            H=int(img_H*ratio)
            newsize = (W,H)
            img = ImageOps.fit(img, newsize, Image.ANTIALIAS)
            px8=int(px7+box_W*1.2)
            py8=int(py7)
            canvas.paste(img,(px8,py8),mask=img.split()[3])
            add_coordinate(start,px8,py8,W,H,obj_name[7])
            
        if(total==9):
            #1st image
            img_list=copy.deepcopy(img_list1)
            img=img_list[0]
            box_W=int((canvas_W)/4)
            box_H=int((canvas_H)/5)
            img_W=img.width
            img_H=img.height
            px=int(box_W/4)
            py=int(box_H/4)
            if(img_W>=img_H):
                ratio=box_W/img_W
            if(img_W<=img_H):
                ratio=box_H/img_H
            if(ratio>1):
                ratio=1
            W=int(img_W*ratio)
            H=int(img_H*ratio)
            newsize = (W,H)
            img = ImageOps.fit(img, newsize, Image.ANTIALIAS)
            canvas.paste(img,(px,py),mask=img.split()[3])
            add_coordinate(start,px,py,W,H,obj_name[0])
            
            #2nd image
            img_list=copy.deepcopy(img_list1)
            img=img_list[1]
            img_W=img.width
            img_H=img.height
            px=int(box_W/4)
            py=int(box_H/4)
            if(img_W>=img_H):
                ratio=box_W/img_W
            if(img_W<=img_H):
                ratio=box_H/img_H
            if(ratio>1):
                ratio=1
            W=int(img_W*ratio)
            H=int(img_H*ratio)
            newsize = (W,H)
            img = ImageOps.fit(img, newsize, Image.ANTIALIAS)
            px2=int(px+box_W*1.2)
            py2=py
            canvas.paste(img,(px2,py2),mask=img.split()[3])
            add_coordinate(start,px2,py2,W,H,obj_name[1])
            
            #3rd image
            img_list=copy.deepcopy(img_list1)
            img=img_list[2]
            img_W=img.width
            img_H=img.height
            px=int(box_W/4)
            py=int(box_H/4)
            if(img_W>=img_H):
                ratio=box_W/img_W
            if(img_W<=img_H):
                ratio=box_H/img_H
            if(ratio>1):
                ratio=1
            W=int(img_W*ratio)
            H=int(img_H*ratio)
            newsize = (W,H)
            img = ImageOps.fit(img, newsize, Image.ANTIALIAS)
            px3=int(px2+box_W*1.2)
            py3=py
            canvas.paste(img,(px3,py3),mask=img.split()[3])
            add_coordinate(start,px3,py3,W,H,obj_name[2])
            
            #4th image
            img_list=copy.deepcopy(img_list1)
            img=img_list[3]
            img_W=img.width
            img_H=img.height
            px=int(box_W/4)
            py=int(box_H/4)
            if(img_W>=img_H):
                ratio=box_W/img_W
            if(img_W<=img_H):
                ratio=box_H/img_H
            if(ratio>1):
                ratio=1
            W=int(img_W*ratio)
            H=int(img_H*ratio)
            newsize = (W,H)
            img = ImageOps.fit(img, newsize, Image.ANTIALIAS)
            px4=px
            py4=int(py+box_H*1.5)
            canvas.paste(img,(px4,py4),mask=img.split()[3])
            add_coordinate(start,px4,py4,W,H,obj_name[3])
            
            #5th image
            img_list=copy.deepcopy(img_list1)
            img=img_list[4]
            img_W=img.width
            img_H=img.height
            px=int(box_W/4)
            py=int(box_H/4)
            if(img_W>=img_H):
                ratio=box_W/img_W
            if(img_W<=img_H):
                ratio=box_H/img_H
            if(ratio>1):
                ratio=1
            W=int(img_W*ratio)
            H=int(img_H*ratio)
            newsize = (W,H)
            img = ImageOps.fit(img, newsize, Image.ANTIALIAS)
            px5=px2
            py5=int(py+box_H*1.5)
            canvas.paste(img,(px5,py5),mask=img.split()[3])
            add_coordinate(start,px5,py5,W,H,obj_name[4])
            
            #6th image
            img_list=copy.deepcopy(img_list1)
            img=img_list[5]
            img_W=img.width
            img_H=img.height
            px=int(box_W/4)
            py=int(box_H/4)
            if(img_W>=img_H):
                ratio=box_W/img_W
            if(img_W<=img_H):
                ratio=box_H/img_H
            if(ratio>1):
                ratio=1
            W=int(img_W*ratio)
            H=int(img_H*ratio)
            newsize = (W,H)
            img = ImageOps.fit(img, newsize, Image.ANTIALIAS)
            px6=px3
            py6=int(py+box_H*1.5)
            canvas.paste(img,(px6,py6),mask=img.split()[3])
            add_coordinate(start,px6,py6,W,H,obj_name[5])
                        
            #7th image
            img_list=copy.deepcopy(img_list1)
            img=img_list[6]
            img_W=img.width
            img_H=img.height
            px=int(box_W/4)
            py=int(box_H/4)
            if(img_W>=img_H):
                ratio=box_W/img_W
            if(img_W<=img_H):
                ratio=box_H/img_H
            if(ratio>1):
                ratio=1
            W=int(img_W*ratio)
            H=int(img_H*ratio)
            newsize = (W,H)
            img = ImageOps.fit(img, newsize, Image.ANTIALIAS)
            px7=int(px)
            py7=int(py5+box_H*1.5)
            canvas.paste(img,(px7,py7),mask=img.split()[3])
            add_coordinate(start,px7,py7,W,H,obj_name[6])
            
            #8th image
            img_list=copy.deepcopy(img_list1)
            img=img_list[7]
            img_W=img.width
            img_H=img.height
            px=int(box_W/4)
            py=int(box_H/4)
            if(img_W>=img_H):
                ratio=box_W/img_W
            if(img_W<=img_H):
                ratio=box_H/img_H
            if(ratio>1):
                ratio=1
            W=int(img_W*ratio)
            H=int(img_H*ratio)
            newsize = (W,H)
            img = ImageOps.fit(img, newsize, Image.ANTIALIAS)
            px8=int(px2)
            py8=int(py7)
            canvas.paste(img,(px8,py8),mask=img.split()[3])
            add_coordinate(start,px8,py8,W,H,obj_name[7])
            
            #9th image
            img_list=copy.deepcopy(img_list1)
            img=img_list[8]
            img_W=img.width
            img_H=img.height
            px=int(box_W/4)
            py=int(box_H/4)
            if(img_W>=img_H):
                ratio=box_W/img_W
            if(img_W<=img_H):
                ratio=box_H/img_H
            if(ratio>1):
                ratio=1
            W=int(img_W*ratio)
            H=int(img_H*ratio)
            newsize = (W,H)
            img = ImageOps.fit(img, newsize, Image.ANTIALIAS)
            px9=int(px3)
            py9=int(py7)
            canvas.paste(img,(px9,py9),mask=img.split()[3])
            add_coordinate(start,px9,py9,W,H,obj_name[8])

# %%
def question_generation():
    # csv2: image_no, count, color, class
    # Create cvs3 from csv2: image_no, question, answer
    import csv
    qg=[]
    with open('CSV/obj_csv2.csv', 'rt')as f:
        data = csv.reader(f)
        for row in data:
            qg.append([row[0],row[1],row[2]])
    f.close()
    file=open('CSV/obj_csv3.csv', 'w', newline='')
    writer = csv.writer(file)
    for k in qg:
        if int(k[1])>1:
            caption="there are "+ k[1]+" "+str(k[2])+"s"
        elif int(k[1])==1:
            caption="there are "+ k[1]+" "+str(k[2])
        question="how many "+str(k[2])+"s are there?"
        ans=k[1]
        writer.writerow([k[0], caption, question, ans]) 
    file.close() 
    
def object_count():
    # csv1: image_no, x, y, w, h, class
    # create csv2 from csv1: image_no, count, color, class
    import csv
    d={}
    with open('CSV/obj_csv1.csv', 'rt')as f:
        data = csv.reader(f)
        for row in data:
            if (row[0],row[-1]) not in d:
                d[(row[0],row[-1])] = 0 
            d[(row[0],row[-1])] += 1
    f.close()
    file=open('CSV/obj_csv2.csv', 'w', newline='')
    writer = csv.writer(file)
    for k in d:
        writer.writerow([k[0],str(d[k]),k[1]]) 
    file.close()

# %%
total_images=0
total_objects=47
for i in range(1,numbers_of_questions):
    objects=[]
    objects_name=[]
    canvas = Image.new("RGB", (canvas_W, canvas_H), (255,255,255))  # create color image
    
    draw = ImageDraw.Draw(canvas)
    
    image_variation=random.randint(1,max_image_variation)
    if(image_variation>1):
        total_images=random.randint(3,9)
        var=np.random.dirichlet(np.ones(2),size=1)
        var1=int(var[0][0]*total_images)
        if(var1==0):
            var1=1
        var2=total_images-var1
        img_index=random.sample(range(0,total_objects-1), 2)
   
        for j in range(0,var1):
            objects.append(imgs[img_index[0]])
            objects_name.append(image_name[img_index[0]])
            
        for j in range(0,var2):
            objects.append(imgs[img_index[1]])
            objects_name.append(image_name[img_index[1]])
            
    if(image_variation==1):
        total_images=random.randint(1,9)
        img_index=random.randint(0,total_objects-1)
        
        for k in range(0,total_images):
            objects.append(imgs[img_index])
            objects_name.append(image_name[img_index])
        
    #print(len(objects)) #print(image_variation) #print(img_index)
    
    add_image(image_variation,canvas,objects,objects_name,total_images,i)
   
    filename = 'output_objects/'+str(i)+'.png'
    canvas.save(filename, "PNG")
    
object_count()
question_generation()

# %%
np.random.dirichlet(np.ones(3),size=1)
# Out:
# array([[0.09774257, 0.71040083, 0.1918566 ]])
